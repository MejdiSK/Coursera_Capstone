# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner

# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# getting  Turkey Largest Cities

# %%
ch='<table><tbody><tr><th>Place Name</th><th>Latitude</th><th>Longitude</th></tr><tr><td><a href="/place/manisa-turkey-29024.html" title="Manisa, Turkey">Manisa, Turkey</a></td><td>38.630554</td><td>27.422222</td></tr><tr><td><a href="/place/diyarbakir-turkey-29023.html" title="Diyarbakir, Turkey">Diyarbakir, Turkey</a></td><td>37.910000</td><td>40.240002</td></tr><tr><td><a href="/place/izmit-kocaeli-turkey-29022.html" title="Izmit, Kocaeli, Turkey">Izmit, Kocaeli, Turkey</a></td><td>40.766666</td><td>29.916668</td></tr><tr><td><a href="/place/gaziantep-turkey-29021.html" title="Gaziantep, Turkey">Gaziantep, Turkey</a></td><td>37.066666</td><td>37.383331</td></tr><tr><td><a href="/place/sanliurfa-turkey-29019.html" title="Sanliurfa, Turkey">Sanliurfa, Turkey</a></td><td>37.158333</td><td>38.791668</td></tr><tr><td><a href="/place/tekirdag-turkey-27881.html" title="Tekirdag, Turkey">Tekirdag, Turkey</a></td><td>40.977779</td><td>27.515278</td></tr><tr><td><a href="/place/adana-turkey-27651.html" title="Adana, Turkey">Adana, Turkey</a></td><td>37.000000</td><td>35.321335</td></tr><tr><td><a href="/place/antalya-turkey-27239.html" title="Antalya, Turkey">Antalya, Turkey</a></td><td>36.884804</td><td>30.704044</td></tr><tr><td><a href="/place/giresun-turkey-24861.html" title="Giresun, Turkey">Giresun, Turkey</a></td><td>40.917534</td><td>38.392654</td></tr><tr><td><a href="/place/yozgat-turkey-24264.html" title="Yozgat, Turkey">Yozgat, Turkey</a></td><td>39.822060</td><td>34.808132</td></tr><tr><td><a href="/place/bolu-turkey-22895.html" title="Bolu, Turkey">Bolu, Turkey</a></td><td>40.731647</td><td>31.589813</td></tr><tr><td><a href="/place/zonguldak-turkey-22509.html" title="Zonguldak, Turkey">Zonguldak, Turkey</a></td><td>41.451733</td><td>31.791344</td></tr><tr><td><a href="/place/van-turkey-22165.html" title="Van, Turkey">Van, Turkey</a></td><td>38.499817</td><td>43.378143</td></tr><tr><td><a href="/place/denizli-turkey-22164.html" title="Denizli, Turkey">Denizli, Turkey</a></td><td>37.783333</td><td>29.094715</td></tr><tr><td><a href="/place/eskisehir-turkey-22089.html" title="Eskişehir, Turkey">Eskişehir, Turkey</a></td><td>39.766193</td><td>30.526714</td></tr><tr><td><a href="/place/artvin-turkey-22081.html" title="Artvin, Turkey">Artvin, Turkey</a></td><td>41.183224</td><td>41.830982</td></tr><tr><td><a href="/place/isparta-turkey-22080.html" title="Isparta, Turkey">Isparta, Turkey</a></td><td>37.768002</td><td>30.561905</td></tr><tr><td><a href="/place/konya-turkey-22040.html" title="Konya, Turkey">Konya, Turkey</a></td><td>37.874641</td><td>32.493156</td></tr><tr><td><a href="/place/nevsehir-turkey-21707.html" title="Nevşehir, Turkey">Nevşehir, Turkey</a></td><td>38.626995</td><td>34.719975</td></tr><tr><td><a href="/place/mersin-turkey-21358.html" title="Mersin, Turkey">Mersin, Turkey</a></td><td>36.812103</td><td>34.641479</td></tr><tr><td><a href="/place/rize-turkey-15374.html" title="Rize, Turkey">Rize, Turkey</a></td><td>41.025513</td><td>40.517666</td></tr><tr><td><a href="/place/kahramanmaras-turkey-12796.html" title="Kahramanmaras, Turkey">Kahramanmaras, Turkey</a></td><td>37.575275</td><td>36.922821</td></tr><tr><td><a href="/place/bursa-turkey-11873.html" title="Bursa, Turkey">Bursa, Turkey</a></td><td>40.193298</td><td>29.074202</td></tr><tr><td><a href="/place/kayseri-turkey-9559.html" title="Kayseri, Turkey">Kayseri, Turkey</a></td><td>38.734802</td><td>35.467987</td></tr><tr><td><a href="/place/elazig-turkey-9384.html" title="Elazığ, Turkey">Elazığ, Turkey</a></td><td>38.680969</td><td>39.226398</td></tr><tr><td><a href="/place/sakarya-turkey-9009.html" title="Sakarya, Turkey">Sakarya, Turkey</a></td><td>40.783333</td><td>30.400000</td></tr><tr><td><a href="/place/hatay-turkey-7282.html" title="Hatay, Turkey">Hatay, Turkey</a></td><td>36.200001</td><td>36.166668</td></tr><tr><td><a href="/place/edirne-turkey-4158.html" title="Edirne, Turkey">Edirne, Turkey</a></td><td>41.674965</td><td>26.583481</td></tr><tr><td><a href="/place/ankara-turkey-2708.html" title="Ankara, Turkey">Ankara, Turkey</a></td><td>39.925533</td><td>32.866287</td></tr><tr><td><a href="/place/istanbul-turkey-2242.html" title="Istanbul, Turkey">Istanbul, Turkey</a></td><td>41.015137</td><td>28.979530</td></tr><tr><td><a href="/place/malatya-turkey-1287.html" title="Malatya, Turkey">Malatya, Turkey</a></td><td>38.356869</td><td>38.309669</td></tr><tr><td><a href="/place/sivas-turkey-993.html" title="Sivas, Turkey">Sivas, Turkey</a></td><td>39.750359</td><td>37.015598</td></tr><tr><td><a href="/place/trabzon-turkey-731.html" title="Trabzon, Turkey">Trabzon, Turkey</a></td><td>41.002697</td><td>39.716763</td></tr><tr><td><a href="/place/izmir-turkey-204.html" title="Izmir, Turkey">Izmir, Turkey</a></td><td>38.423733</td><td>27.142826</td></tr><tr><td><a href="/place/amasya-turkey-88.html" title="Amasya, Turkey">Amasya, Turkey</a></td><td>40.652382</td><td>35.828819</td></tr><tr><td><a href="/place/afyonkarahisar-turkey-19.html" title="Afyonkarahisar, Turkey">Afyonkarahisar, Turkey</a></td><td>38.756886</td><td>30.538704</td></tr></tbody></table>'
import pandas as pd
# !conda install --y lxml
df=pd.read_html(ch)
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.

# %%
np.shape(df)
# Out:
# (1, 36, 3)

# %%
df
import numpy as np
df4=tuple(df)
df3=np.asarray(df4)
k=np.reshape(df3, (36, 3))
Cities=pd.DataFrame(data=k,columns=['City','Latitude','Longitude'])
Cities['City']=Cities['City'].str.replace(', Turkey',' ')
Cities.info()
Cities
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   City       36 non-null     object
#  1   Latitude   36 non-null     object
#  2   Longitude  36 non-null     object
# dtypes: object(3)
# memory usage: 992.0+ bytes
#                City Latitude Longitude
# 0           Manisa   38.6306   27.4222
# 1       Diyarbakir     37.91     40.24
# 2   Izmit, Kocaeli   40.7667   29.9167
# 3        Gaziantep   37.0667   37.3833
# 4        Sanliurfa   37.1583   38.7917
# 5         Tekirdag   40.9778   27.5153
# 6            Adana        37   35.3213
# 7          Antalya   36.8848    30.704
# 8          Giresun   40.9175   38.3927
# 9           Yozgat   39.8221   34.8081
# 10            Bolu   40.7316   31.5898
# 11       Zonguldak   41.4517   31.7913
# 12             Van   38.4998   43.3781
# 13         Denizli   37.7833   29.0947
# ...

# %% [markdown]
# Get the venues using Fourspare

# %%
CLIENT_ID = 'K0FKTHOOWLLDDKLIDLAXZDM21OD0EU2KXDMEGHNGUZN25JYB' # your Foursquare ID
CLIENT_SECRET = 'QNIC2EKJO53MDEQDVXEO54T0GHODOIS2KG4GOSB1UACJHDJQ' # your Foursquare Secret
VERSION = '20180605'
LIMIT = 400
#giving the Ids of categories related to the three important types of Tourism (seaside,historic,natural)
list_venues_categories='52e81612bcbc57f1066b7a22,4bf58dd8d48988d1e4941735,4bf58dd8d48988d15f941735,52e81612bcbc57f1066b7a23,4bf58dd8d48988d161941735,4bf58dd8d48988d163941735,4eb1d4dd4b900d56c88a45fd,4bf58dd8d48988d159941735,4eb1d4d54b900d56c88a45fc,56aa371be4b08b9a8d573560,4bf58dd8d48988d1e2941735,4bf58dd8d48988d181941735,4deefb944765f83613cdba6e,4bf58dd8d48988d131941735'
def getVenues(names, latitudes, longitudes, radius=10000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&v={}&categoryId={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION,
            list_venues_categories,
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['venues']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['name'], 
            v['location']['lat'], 
            v['location']['lng'],  
            v['categories'][0]['name']) for v in results])
        
       #Creating dataframe containing venues foreach city  
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['City Name', 
                  'City Latitude', 
                  'City Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

      #applying last function created with args taken from our first dataframe created 
Turkey_venues = getVenues(names=Cities['City'],latitudes=Cities['Latitude'],longitudes=Cities['Longitude'])

# %%
Turkey_venues
# Out:
#             City Name  City Latitude  City Longitude  \
# 0             Manisa       38.630554       27.422222
# 1             Manisa       38.630554       27.422222
# 2             Manisa       38.630554       27.422222
# 3             Manisa       38.630554       27.422222
# 4             Manisa       38.630554       27.422222
# ...               ...            ...             ...
# 1793  Afyonkarahisar       38.756886       30.538704
# 1794  Afyonkarahisar       38.756886       30.538704
# 1795  Afyonkarahisar       38.756886       30.538704
# 1796  Afyonkarahisar       38.756886       30.538704
# 1797  Afyonkarahisar       38.756886       30.538704
#
#                                        Venue  Venue Latitude  Venue Longitude  \
# 0                Şehit Ömer Halisdemir Parkı       38.625438        27.429206
# 1                               Sultan Parkı       38.610314        27.426263
# 2                              Çiftlik Parkı       38.610814        27.368089
# ...

# %%
#eliminating some venues corrsponding to other categories not mentioned earlier (153 rows )
Turkey_venues=Turkey_venues.loc[(Turkey_venues['Venue Category'] == 'Park')|(Turkey_venues['Venue Category'] ==  'Mountain')|(Turkey_venues['Venue Category'] ==  'Historic Site')|(Turkey_venues['Venue Category'] == 'Botanical Garden')|(Turkey_venues['Venue Category'] ==  'Mosque')|( Turkey_venues['Venue Category'] == 'Field')| (Turkey_venues['Venue Category'] == 'Campground')|(Turkey_venues['Venue Category'] ==  'Lake')|(Turkey_venues['Venue Category'] == 'Other Great Outdoors')|(Turkey_venues['Venue Category']== 'History Museum')|(Turkey_venues['Venue Category'] ==  'Castle')|(Turkey_venues['Venue Category'] ==  'Forest')|(Turkey_venues['Venue Category'] ==  'River')|(Turkey_venues['Venue Category'] ==  'Beach')|(Turkey_venues['Venue Category']== 'Monument / Landmark')|(Turkey_venues['Venue Category']== 'Waterfall')|(Turkey_venues['Venue Category']=='Science Museum')|(Turkey_venues['Venue Category'] ==  'Nudist Beach')|(Turkey_venues['Venue Category'] ==  'Museum')|(Turkey_venues['Venue Category'] == 'Water Park' )|(Turkey_venues['Venue Category'] ==  'Temple')|(Turkey_venues['Venue Category'] ==  'Art Museum')|(Turkey_venues['Venue Category'] ==  'Scenic Lookout')|(Turkey_venues['Venue Category'] ==  'Garden')|(Turkey_venues['Venue Category'] ==  'Church')|(Turkey_venues['Venue Category'] ==  'National Park')|( Turkey_venues['Venue Category'] == 'Surf Spot')| (Turkey_venues['Venue Category'] == 'Cave')|(Turkey_venues['Venue Category'] ==  'Prayer Room')| (Turkey_venues['Venue Category'] == 'Synagogue')]
Turkey_venues
# Out:
#             City Name  City Latitude  City Longitude  \
# 0             Manisa       38.630554       27.422222
# 1             Manisa       38.630554       27.422222
# 2             Manisa       38.630554       27.422222
# 3             Manisa       38.630554       27.422222
# 4             Manisa       38.630554       27.422222
# ...               ...            ...             ...
# 1792  Afyonkarahisar       38.756886       30.538704
# 1794  Afyonkarahisar       38.756886       30.538704
# 1795  Afyonkarahisar       38.756886       30.538704
# 1796  Afyonkarahisar       38.756886       30.538704
# 1797  Afyonkarahisar       38.756886       30.538704
#
#                                        Venue  Venue Latitude  Venue Longitude  \
# 0                Şehit Ömer Halisdemir Parkı       38.625438        27.429206
# 1                               Sultan Parkı       38.610314        27.426263
# 2                              Çiftlik Parkı       38.610814        27.368089
# ...

# %%
#dropping columns not needed 
Turkeyy_venues=Turkey_venues.drop(columns=['City Latitude','City Longitude','Venue','Venue Latitude','Venue Longitude'],inplace=True)
Turkeyy_venues
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py:4170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#grouping venues by category
Turkey_venuess=pd.get_dummies(Turkey_venues,columns=['Venue Category'])
Turkey_venuess=Turkey_venuess.groupby('City Name').sum()
Turkey_venuess
# Out:
#                  Venue Category_Art Museum  Venue Category_Beach  \
# City Name
# Adana                                    1                     1
# Afyonkarahisar                           0                     0
# Amasya                                   0                     0
# Ankara                                   0                     0
# Antalya                                  0                    27
# Artvin                                   0                     1
# Bolu                                     0                     0
# Bursa                                    0                     0
# Denizli                                  0                     0
# Diyarbakir                               0                     0
# Edirne                                   0                     0
# Elazığ                                   0                     1
# Eskişehir                                2                     0
# ...

# %%
Turkey_venuess.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, Adana  to Zonguldak
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Venue Category_Art Museum            36 non-null     uint8
#  1   Venue Category_Beach                 36 non-null     uint8
#  2   Venue Category_Botanical Garden      36 non-null     uint8
#  3   Venue Category_Campground            36 non-null     uint8
#  4   Venue Category_Castle                36 non-null     uint8
#  5   Venue Category_Cave                  36 non-null     uint8
#  6   Venue Category_Church                36 non-null     uint8
#  7   Venue Category_Field                 36 non-null     uint8
#  8   Venue Category_Forest                36 non-null     uint8
#  9   Venue Category_Garden                36 non-null     uint8
#  10  Venue Category_Historic Site         36 non-null     uint8
# ...

# %%
Turkey_venuess['Venue Category_Art Museum']=Turkey_venuess['Venue Category_Art Museum']+Turkey_venuess['Venue Category_Castle']+Turkey_venuess['Venue Category_Church']+Turkey_venuess['Venue Category_Historic Site']+Turkey_venuess['Venue Category_History Museum']+Turkey_venuess['Venue Category_Monument / Landmark']+Turkey_venuess['Venue Category_Mosque']+Turkey_venuess['Venue Category_Museum']+Turkey_venuess['Venue Category_Prayer Room']+Turkey_venuess['Venue Category_Science Museum']+Turkey_venuess['Venue Category_Synagogue']+Turkey_venuess['Venue Category_Temple']
Turkey_venuess['Venue Category_Waterfall']=Turkey_venuess['Venue Category_Waterfall']+Turkey_venuess['Venue Category_Water Park']+Turkey_venuess['Venue Category_River']+Turkey_venuess['Venue Category_Park']+Turkey_venuess['Venue Category_Other Great Outdoors']+Turkey_venuess['Venue Category_National Park']+Turkey_venuess['Venue Category_Mountain']+Turkey_venuess['Venue Category_Lake']+Turkey_venuess['Venue Category_Botanical Garden']+Turkey_venuess['Venue Category_Field']+Turkey_venuess['Venue Category_Garden']+Turkey_venuess['Venue Category_Forest']+Turkey_venuess['Venue Category_Cave']+Turkey_venuess['Venue Category_Campground']
Turkey_venuess['Venue Category_Beach']=Turkey_venuess['Venue Category_Surf Spot']+Turkey_venuess['Venue Category_Beach']

# %%
Turkey_venues=Turkey_venuess.drop(columns=['Venue Category_Castle','Venue Category_Church','Venue Category_Historic Site','Venue Category_History Museum','Venue Category_Monument / Landmark','Venue Category_Mosque','Venue Category_Museum','Venue Category_Prayer Room','Venue Category_Science Museum','Venue Category_Synagogue','Venue Category_Temple','Venue Category_Water Park','Venue Category_River','Venue Category_Park','Venue Category_Other Great Outdoors','Venue Category_National Park','Venue Category_Mountain','Venue Category_Lake','Venue Category_Botanical Garden','Venue Category_Field','Venue Category_Garden','Venue Category_Forest','Venue Category_Cave','Venue Category_Campground','Venue Category_Surf Spot','Venue Category_Scenic Lookout','Venue Category_Nudist Beach'],inplace=True)

# %%
Turkey_venuess.rename({'Venue Category_Art Museum':'Historic_venues','Venue Category_Beach':'Seaside_venues','Venue Category_Waterfall':'Natural_venues'},axis=1,inplace=True)
Turkey_venuess
# Out:
#                  Historic_venues  Seaside_venues  Natural_venues
# City Name
# Adana                          6               1              34
# Afyonkarahisar                 7               0              39
# Amasya                        19               0              30
# Ankara                         9               0              35
# Antalya                        3              27              13
# Artvin                         4               1              42
# Bolu                          11               0              33
# Bursa                         12               0              32
# Denizli                        5               0              41
# Diyarbakir                    17               0              27
# Edirne                        18               0              25
# Elazığ                        13               1              31
# Eskişehir                     13               0              35
# ...

# %%
TR_venues=Turkey_venuess.reset_index()

# %%
TR_venues
# Out:
#           City Name  Historic_venues  Seaside_venues  Natural_venues
# 0            Adana                 6               1              34
# 1   Afyonkarahisar                 7               0              39
# 2           Amasya                19               0              30
# 3           Ankara                 9               0              35
# 4          Antalya                 3              27              13
# 5           Artvin                 4               1              42
# 6             Bolu                11               0              33
# 7            Bursa                12               0              32
# 8          Denizli                 5               0              41
# 9       Diyarbakir                17               0              27
# 10          Edirne                18               0              25
# 11          Elazığ                13               1              31
# 12       Eskişehir                13               0              35
# ...

# %%
from sklearn.cluster import KMeans

# %%
#clustering with KMeans
K_clusters=3
kmeans=KMeans(n_clusters=K_clusters,random_state=0).fit(Turkey_venuess)

# %%
kmeans.labels_[:]
# Out:
# array([0, 0, 2, 0, 1, 0, 0, 0, 0, 2, 2, 2, 0, 0, 1, 0, 0, 2, 0, 0, 0, 0,
#        0, 0, 0, 0, 2, 0, 0, 2, 2, 1, 2, 0, 0, 1], dtype=int32)

# %%
# add clustering labels
TR_venues.insert(0, 'Cluster Labels', kmeans.labels_)
TR_venues
# Out:
#     Cluster Labels        City Name  Historic_venues  Seaside_venues  \
# 0                0           Adana                 6               1
# 1                0  Afyonkarahisar                 7               0
# 2                2          Amasya                19               0
# 3                0          Ankara                 9               0
# 4                1         Antalya                 3              27
# 5                0          Artvin                 4               1
# 6                0            Bolu                11               0
# 7                0           Bursa                12               0
# 8                0         Denizli                 5               0
# 9                2      Diyarbakir                17               0
# 10               2          Edirne                18               0
# 11               2          Elazığ                13               1
# 12               0       Eskişehir                13               0
# ...

# %%
#adding columns of most trending venues in datafrmae Cities
indicators = {3:'st',4:'nd',5:'rd'}
p=1
for c in range(3,13):
    try:
        Cities.insert(loc=c,column='{}{} Most Trending Venue'.format(p, indicators[c]),value='nan')
        p=p+1
    except:
        Cities.insert(loc=c,column='{}th Most Trending Venue'.format(p),value='nan')
        p=p+1
Cities
# Out:
#                City Latitude Longitude 1st Most Trending Venue  \
# 0           Manisa   38.6306   27.4222                     nan
# 1       Diyarbakir     37.91     40.24                     nan
# 2   Izmit, Kocaeli   40.7667   29.9167                     nan
# 3        Gaziantep   37.0667   37.3833                     nan
# 4        Sanliurfa   37.1583   38.7917                     nan
# 5         Tekirdag   40.9778   27.5153                     nan
# 6            Adana        37   35.3213                     nan
# 7          Antalya   36.8848    30.704                     nan
# 8          Giresun   40.9175   38.3927                     nan
# 9           Yozgat   39.8221   34.8081                     nan
# 10            Bolu   40.7316   31.5898                     nan
# 11       Zonguldak   41.4517   31.7913                     nan
# 12             Van   38.4998   43.3781                     nan
# 13         Denizli   37.7833   29.0947                     nan
# ...

# %%
#Getting the 10 most trending venues for each city 

CLIENT_ID = 'K0FKTHOOWLLDDKLIDLAXZDM21OD0EU2KXDMEGHNGUZN25JYB' # your Foursquare ID
CLIENT_SECRET = 'QNIC2EKJO53MDEQDVXEO54T0GHODOIS2KG4GOSB1UACJHDJQ' # your Foursquare Secret
VERSION = '20180605'
for k in Cities.iterrows():
    i=0
    j=3
    url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION,
            k[1]['Latitude'], 
            k[1]['Longitude'], 
            2000, 
            10)
             # make the GET request
    results = requests.get(url).json()
    trending_venues =results['response']['venues']
    while i<10 and j<14:
        try:
            Cities.iloc[k[0],j]=trending_venues[i]['name']
            j=j+1
            i=i+1
        except:
            break
    

Cities
# Out:
#                City Latitude Longitude 1st Most Trending Venue  \
# 0           Manisa   38.6306   27.4222            Manisa Çarşı
# 1       Diyarbakir     37.91     40.24             Sülüklü Han
# 2   Izmit, Kocaeli   40.7667   29.9167             İzmit Çarşı
# 3        Gaziantep   37.0667   37.3833         Gaziantep Çarşı
# 4        Sanliurfa   37.1583   38.7917             Novada Park
# 5         Tekirdag   40.9778   27.5153          Tekirdağ Sahil
# 6            Adana        37   35.3213             Adana Çarşı
# 7          Antalya   36.8848    30.704             MarkAntalya
# 8          Giresun   40.9175   38.3927          Giresun Sahili
# 9           Yozgat   39.8221   34.8081                     nan
# 10            Bolu   40.7316   31.5898    İzzet Baysal Caddesi
# 11       Zonguldak   41.4517   31.7913         Zonguldak Çarşı
# 12             Van   38.4998   43.3781                 Van AVM
# 13         Denizli   37.7833   29.0947           Çınar Meydanı
# ...

# %%
CT=Cities.merge(TR_venues,left_on='City',right_on='City Name')
CT.drop(columns=['Historic_venues','Seaside_venues','Natural_venues','City Name'],inplace=True)
CT
# Out:
#                City Latitude Longitude 1st Most Trending Venue  \
# 0           Manisa   38.6306   27.4222            Manisa Çarşı
# 1       Diyarbakir     37.91     40.24             Sülüklü Han
# 2   Izmit, Kocaeli   40.7667   29.9167             İzmit Çarşı
# 3        Gaziantep   37.0667   37.3833         Gaziantep Çarşı
# 4        Sanliurfa   37.1583   38.7917             Novada Park
# 5         Tekirdag   40.9778   27.5153          Tekirdağ Sahil
# 6            Adana        37   35.3213             Adana Çarşı
# 7          Antalya   36.8848    30.704             MarkAntalya
# 8          Giresun   40.9175   38.3927          Giresun Sahili
# 9           Yozgat   39.8221   34.8081                     nan
# 10            Bolu   40.7316   31.5898    İzzet Baysal Caddesi
# 11       Zonguldak   41.4517   31.7913         Zonguldak Çarşı
# 12             Van   38.4998   43.3781                 Van AVM
# 13         Denizli   37.7833   29.0947           Çınar Meydanı
# ...

# %%
print ('cluster 0')
CT.loc[CT['Cluster Labels']==0]
# Out:
# cluster 0
#                City Latitude Longitude 1st Most Trending Venue  \
# 0           Manisa   38.6306   27.4222            Manisa Çarşı
# 2   Izmit, Kocaeli   40.7667   29.9167             İzmit Çarşı
# 3        Gaziantep   37.0667   37.3833         Gaziantep Çarşı
# 6            Adana        37   35.3213             Adana Çarşı
# 9           Yozgat   39.8221   34.8081                     nan
# 10            Bolu   40.7316   31.5898    İzzet Baysal Caddesi
# 12             Van   38.4998   43.3781                 Van AVM
# 13         Denizli   37.7833   29.0947           Çınar Meydanı
# 14       Eskişehir   39.7662   30.5267                  Adalar
# 15          Artvin   41.1832    41.831                     nan
# 16         Isparta    37.768   30.5619           Isparta Çarşı
# 17           Konya   37.8746   32.4932                   Konya
# 19          Mersin   36.8121   34.6415            Mersin Çarşı
# 20            Rize   41.0255   40.5177             Rize Meydan
# ...

# %%
print ('cluster 1')
CT.loc[CT['Cluster Labels']==1]
# Out:
# cluster 1
#           City Latitude Longitude 1st Most Trending Venue  \
# 5    Tekirdag   40.9778   27.5153          Tekirdağ Sahil
# 7     Antalya   36.8848    30.704             MarkAntalya
# 8     Giresun   40.9175   38.3927          Giresun Sahili
# 11  Zonguldak   41.4517   31.7913         Zonguldak Çarşı
#
#      2nd Most Trending Venue 3rd Most Trending Venue 4th Most Trending Venue  \
# 5             Tekirdağ Çarşı                     nan                     nan
# 7                    Kaleiçi             Luna Garden                 Antalya
# 8   Culina Cafe & Restaurant                     nan                     nan
# 11                       nan                     nan                     nan
#
#    5th Most Trending Venue       6th Most Trending Venue  \
# 5                      nan                           nan
# 7                   Çöplük  Holly Stone Performance Hall
# 8                      nan                           nan
# ...

# %%
print ('cluster 2')
CT.loc[CT['Cluster Labels']==2]
# Out:
# cluster 2
#            City Latitude Longitude 1st Most Trending Venue  \
# 1   Diyarbakir     37.91     40.24             Sülüklü Han
# 4    Sanliurfa   37.1583   38.7917             Novada Park
# 18    Nevşehir    38.627     34.72                     nan
# 24      Elazığ    38.681   39.2264            Gazi Caddesi
# 27      Edirne    41.675   26.5835           Erasta Edirne
# 29    Istanbul   41.0151   28.9795          Eminönü Sahili
# 31       Sivas   39.7504   37.0156      Cumhuriyet Meydanı
# 32     Trabzon   41.0027   39.7168            Meydan Parkı
# 34      Amasya   40.6524   35.8288            Amasya Çarşı
#
#    2nd Most Trending Venue 3rd Most Trending Venue 4th Most Trending Venue  \
# 1               Diyarbakır        Firuze Kahve Lab                     nan
# 4            Gönül Kahvesi            Bahçelievler               Karaköprü
# 18                     nan                     nan                     nan
# ...
